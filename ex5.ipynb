# %%
import pandas as pd

# %%
df = pd.read_csv("gfg.txt",sep=" ")

# %%
df
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Index: []

# %%
#5b

# %%
df = pd.read_csv("gfg.txt", sep=" ", header=None, names=["team1","team2"])

# %%
df
# Out:
#                team1  team2
# 1 2 3 4 5 6 7      8      9

# %%
#5c

# %%
import pandas as pd

# %%
df= pd.read_table("gfg.txt", delimiter=" ");

# %%
df
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Index: []

# %%
df = pd.read_excel("SampleData.xlsx");

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                            Online Instruction Page
# 4          NaN        NaN                              Sample Data for Excel
# 5          NaN        NaN                           Office Supply Sales Data
# 6          NaN        NaN                                                NaN
# 7          NaN        NaN                                  Related tutorials
# 8          NaN        NaN                            More Excel Sample Files
# 9          NaN        NaN                                 Named Excel Tables
# 10         NaN        NaN                                    Data Entry Tips
# ...

# %%
openpyxl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 openpyxl
#
# NameError: name 'openpyxl' is not defined

# %%
pip install openpyxl
# Out:
# ...
#      ------------------------------------ 242.1/242.1 kB 743.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sheet1 = pd.read_excel("Book.xlsx", sheet_name=0, index_col=0);
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
sheet1
# Out:
#                                    Country    Product Discount Band  \
# Segment
# Midmarket                           France      Paseo          None
# Small Business                      Mexico      Paseo          None
# Government                          France        VTT          None
# Enterprise        United States of America  Carretera           Low
# Small Business    United States of America    Montana           Low
# Channel Partners  United States of America   Amarilla           Low
# Government                         Germany    Montana           Low
# Government                          Mexico      Paseo           Low
# Government        United States of America       Velo           Low
# Government                          Canada       Velo           Low
# Government        United States of America        VTT           Low
# Government                          Canada      Paseo        Medium
# Government                          Mexico    Montana        Medium
# ...

# %%
sheet2 = pd.read_excel("Book 1.xlsx",sheet_name=1, index_col=0);

# %%
newdata = pd.concat([sheet1,sheet2])

# %%
newdata
# Out:
#                                    Country    Product Discount Band  \
# Segment
# Midmarket                           France      Paseo          None
# Small Business                      Mexico      Paseo          None
# Government                          France        VTT          None
# Enterprise        United States of America  Carretera           Low
# Small Business    United States of America    Montana           Low
# Channel Partners  United States of America   Amarilla           Low
# Government                         Germany    Montana           Low
# Government                          Mexico      Paseo           Low
# Government        United States of America       Velo           Low
# Government                          Canada       Velo           Low
# Government        United States of America        VTT           Low
# Government                          Canada      Paseo        Medium
# Government                          Mexico    Montana        Medium
# ...

# %%
import urllib.request
url="http://textfiles.com/adventure/aencounter.txt";
file = urllib.request.urlopen(url);

# %%
 for line in file:
        decode = line.decode("utf-8")
        print(decode)
# Out:
# ***************************************
#
# *                                     *
#
# *            HOW TO SOLVE:            *
#
# *                                     *
#
# *        THE ALPINE ENCOUNTER         *
#
# *                                     *
#
# ***************************************
#
#
#
# THIS ADVENTURE IS TRULY AN ENIGMA.
#
# IT CAN BE SOLVED IN HUNDREDS OF MOVES
#
# OR HALF A DOZEN....
#
# WELL I HAVEN'T PLAYED THE HUNDRED MOVE
#
# VERSION...SO HERE'S THE SHORT ONE.
#
#
#
# COMMANDS IN BRACKETS:
#
#
#
#  [N] THIS WILL PUT YOU INSIDE.
#
#  [N] THIS WILL GET YOU NEAR THE DESK.
#
#  [W] THIS WILL GET YOU TO THE REGIS-
#
#      TRATION DESK.
#
#  [REGISTER] A FORMALITY. FILL IN ANY
#
#    NAME, ADDRESS, ETC.
#
#  [WAIT] FOR A BLONDE WOMAN TO APPEAR.
#
#    SHE'LL APPEAR AROUND 9:45.
#
#    AT THAT POINT PRESS A KEY (NOT
#
#    BEFORE.)
#
#  [LOOK BACKPACK] THIS WILL UNCOVER A
#
#    VASE.
#
#  [TAKE VASE] YOU HAVE THE VITAL
#
#    INFORMATION UNDER YOUR NOSE!
#
# ...

# %%
import pandas as pd

blood_transfusion_uci_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/blood-transfusion/transfusion.data'

df = pd.read_csv(blood_transfusion_uci_url)



import uci_dataset as dataset

blood_transfusion_df = dataset.load_blood_transfusion()

cervical_cancer_df = dataset.load_cervical_cancer()

diabetic_df = dataset.load_diabetic()

obesity_levels_df = dataset.load_obesity_levels()

#chronic_kidney_disease_df = dataset.load_chronic_kidney_disease()

# %%
pip install uci_dataset
# Out:
# ...
#      ---------------------------------------- 40.1/40.1 MB 4.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 8.2/8.2 MB 4.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 298.0/298.0 kB 6.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
