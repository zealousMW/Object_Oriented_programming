# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head() # show first five
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.mean()
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# sepal.length    5.80
# sepal.width     3.00
# petal.length    4.35
# petal.width     1.30
# dtype: float64

# %%
df.count()
# Out:
# sepal.length    150
# sepal.width     150
# petal.length    150
# petal.width     150
# variety         150
# dtype: int64

# %%
df.var()
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# sepal.length    0.685694
# sepal.width     0.189979
# petal.length    3.116278
# petal.width     0.581006
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# sepal.length    0.828066
# sepal.width     0.435866
# petal.length    1.765298
# petal.width     0.762238
# dtype: float64

# %%
df.quantile(0,1)
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\3399630545.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0,1)
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: 0.0, Length: 150, dtype: float64

# %%
df.quantile(0.95)
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\1903517651.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.95)
# sepal.length    7.255
# sepal.width     3.800
# petal.length    6.100
# petal.width     2.300
# Name: 0.95, dtype: float64

# %%
df.quantile(0.75)
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\3799946287.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.75)
# sepal.length    6.4
# sepal.width     3.3
# petal.length    5.1
# petal.width     1.8
# Name: 0.75, dtype: float64

# %%
df.quantile(0.25)
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\3656653379.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.25)
# sepal.length    5.1
# sepal.width     2.8
# petal.length    1.6
# petal.width     0.3
# Name: 0.25, dtype: float64

# %%
df.quantile(0.25) - df.quantile(0.75)
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_3416\3938210929.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.25) - df.quantile(0.75)
# sepal.length   -1.3
# sepal.width    -0.5
# petal.length   -3.5
# petal.width    -1.5
# dtype: float64

# %%
df.max()
# Out:
# sepal.length          7.9
# sepal.width           4.4
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object

# %%
df.min()
# Out:
# sepal.length       4.3
# sepal.width        2.0
# petal.length       1.0
# petal.width        0.1
# variety         Setosa
# dtype: object

# %%
iris_group = df.groupby('variety')

# %%
print(iris_group)

# %%
iris_group.mean()
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa             5.006        3.428         1.462        0.246
# Versicolor         5.936        2.770         4.260        1.326
# Virginica          6.588        2.974         5.552        2.026

# %%
iris_group.quantile(0.75)
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.2        3.675         1.575          0.3
# Versicolor           6.3        3.000         4.600          1.5
# Virginica            6.9        3.175         5.875          2.3

# %%
iris_group.quantile(0.75) - iris_group.quantile(0.25)
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa             0.400        0.475         0.175          0.1
# Versicolor         0.700        0.475         0.600          0.3
# Virginica          0.675        0.375         0.775          0.5

# %%
iris_group.describe()
# Out:
#            sepal.length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# variety
# Setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal.width         ... petal.length      petal.width         \
#                  count   mean  ...          75%  max       count   mean
# variety                        ...
# Setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# Versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# variety
# Setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# Versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# Virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
#pima

# %%
df = pd.read_csv('pima-indians-diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Class
# 0                       0.627   50      1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Class
# 0                     0.627   50      1
# 1                     0.351   31      0
# 2                     0.672   32      1
# 3                     0.167   21      0
# 4                     2.288   33      1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Class                     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age       Class
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Class                       768
# dtype: int64

# %%
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Class                         0.348958
# dtype: float64

# %%
df.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Class                         0.0000
# dtype: float64

# %%
df.var()
# Out:
# Pregnancies                    11.354056
# Glucose                      1022.248314
# BloodPressure                 374.647271
# SkinThickness                 254.473245
# Insulin                     13281.180078
# BMI                            62.159984
# DiabetesPedigreeFunction        0.109779
# Age                           138.303046
# Class                           0.227483
# dtype: float64

# %%
df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Class                         0.476951
# dtype: float64

# %%
df.quantile(0.1)
# Out:
# Pregnancies                  0.000
# Glucose                     85.000
# BloodPressure               54.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                         23.600
# DiabetesPedigreeFunction     0.165
# Age                         22.000
# Class                        0.000
# Name: 0.1, dtype: float64

# %%
df.quantile(0.25)
# Out:
# Pregnancies                  1.00000
# Glucose                     99.00000
# BloodPressure               62.00000
# SkinThickness                0.00000
# Insulin                      0.00000
# BMI                         27.30000
# DiabetesPedigreeFunction     0.24375
# Age                         24.00000
# Class                        0.00000
# Name: 0.25, dtype: float64

# %%
df.quantile(0.75)
# Out:
# Pregnancies                   6.00000
# Glucose                     140.25000
# BloodPressure                80.00000
# SkinThickness                32.00000
# Insulin                     127.25000
# BMI                          36.60000
# DiabetesPedigreeFunction      0.62625
# Age                          41.00000
# Class                         1.00000
# Name: 0.75, dtype: float64

# %%
df.quantile(0.75)-df.quantile(0.25)
# Out:
# Pregnancies                   5.0000
# Glucose                      41.2500
# BloodPressure                18.0000
# SkinThickness                32.0000
# Insulin                     127.2500
# BMI                           9.3000
# DiabetesPedigreeFunction      0.3825
# Age                          17.0000
# Class                         1.0000
# dtype: float64

# %%
df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Class                         1.00
# dtype: float64

# %%
df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Class                        0.000
# dtype: float64

# %%
grp = df.groupby('Class')

# %%
grp.mean()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Class
# 0         3.298000  109.980000      68.184000      19.664000   68.792000
# 1         4.865672  141.257463      70.824627      22.164179  100.335821
#
#              BMI  DiabetesPedigreeFunction        Age
# Class
# 0      30.304200                  0.429734  31.190000
# 1      35.142537                  0.550500  37.067164

# %%
grp.quantile(0.25)
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Class
# 0             1.00     93.0           62.0            0.0      0.0  25.4
# 1             1.75    119.0           66.0            0.0      0.0  30.8
#
#        DiabetesPedigreeFunction   Age
# Class
# 0                       0.22975  23.0
# 1                       0.26250  28.0

# %%
grp.quantile(0.75) - grp.quantile(0.25)
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# Class
# 0             4.00     32.0           16.0           31.0   105.00  9.900
# 1             6.25     48.0           16.0           36.0   167.25  7.975
#
#        DiabetesPedigreeFunction   Age
# Class
# 0                        0.3320  14.0
# 1                        0.4655  16.0

# %%
grp.describe()
# Out:
#       Pregnancies                                                Glucose  \
#             count      mean       std  min   25%  50%  75%   max   count
# Class
# 0           500.0  3.298000  3.017185  0.0  1.00  2.0  5.0  13.0   500.0
# 1           268.0  4.865672  3.741239  0.0  1.75  4.0  8.0  17.0   268.0
#
#                    ... DiabetesPedigreeFunction           Age             \
#              mean  ...                      75%    max  count       mean
# Class              ...
# 0      109.980000  ...                  0.56175  2.329  500.0  31.190000
# 1      141.257463  ...                  0.72800  2.420  268.0  37.067164
#
#
#              std   min   25%   50%   75%   max
# Class
# 0      11.667655  21.0  23.0  27.0  37.0  81.0
# 1      10.968254  21.0  28.0  36.0  44.0  70.0
#
# [2 rows x 64 columns]

# %%
df.value_counts("Class")
# Out:
# Class
# 0    500
# 1    268
# dtype: int64

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Class                       0.635017
# dtype: float64

# %%
df.kurt()
# Out:
# Pregnancies                 0.159220
# Glucose                     0.640780
# BloodPressure               5.180157
# SkinThickness              -0.520072
# Insulin                     7.214260
# BMI                         3.290443
# DiabetesPedigreeFunction    5.594954
# Age                         0.643159
# Class                      -1.600930
# dtype: float64

# %%
df.Age
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
df.Class
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Class, Length: 768, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(df.Age,df.Class,marker='+', color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(
    df[['Age','Pregnancies']],
    df.Class,
    test_size=0.3,
   
)

# %%
xtest
# Out:
#      Age  Pregnancies
# 423   21            2
# 166   22            3
# 175   36            8
# 761   43            9
# 636   48            5
# ..   ...          ...
# 256   30            3
# 40    26            3
# 434   36            1
# 462   39            8
# 467   25            0
#
# [231 rows x 2 columns]

# %%
xtrain
# Out:
#      Age  Pregnancies
# 15    32            7
# 16    31            0
# 413   21            1
# 703   41            2
# 126   30            3
# ..   ...          ...
# 682   22            0
# 732   24            2
# 465   21            0
# 153   23            1
# 723   42            5
#
# [537 rows x 2 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
x = model.predict(xtest)

# %%
model.score(xtest,ytest)
# Out:
# 0.6753246753246753

# %%
model.predict([[3,50]])
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
df[['Pregnancies','Class']]
# Out:
#      Pregnancies  Class
# 0              6      1
# 1              1      0
# 2              8      1
# 3              1      0
# 4              0      1
# ..           ...    ...
# 763           10      0
# 764            2      0
# 765            5      0
# 766            1      1
# 767            1      0
#
# [768 rows x 2 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')

# %%
sns.countplot(x='variety', data= df) #7a
# Out:
# <AxesSubplot: xlabel='variety', ylabel='count'>

# %%
sns.scatterplot(x='sepal.length', y='sepal.width', hue='variety',data=df)
# Out:
# <AxesSubplot: xlabel='sepal.length', ylabel='sepal.width'>

# %%
sns.scatterplot(x='sepal.length', y='sepal.width', hue='variety',data=df) #7b
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
sns.scatterplot(x='petal.length', y ='petal.width', hue='variety',data=df)
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
sns.pairplot(df,hue='variety',height=2)

# %%
fig,axes = plt.subplots(2,2,figsize=(10,10))
axes[0,0].set_title("sepal length")
axes[0,0].hist(df['sepal.length'],bins=8)

axes[0,1].set_title("sepal width")
axes[0,1].hist(df['sepal.width'],bins=4)

axes[1,0].set_title("petal lenght")
axes[1,0].hist(df['petal.length'],bins=6)

axes[1,1].set_title("sepal width")
axes[1,1].hist(df['petal.width'],bins=6)
# Out:
# (array([48.,  2., 15., 37., 25., 23.]),
#  array([0.1, 0.5, 0.9, 1.3, 1.7, 2.1, 2.5]),
#  <BarContainer object of 6 artists>)

# %%
plt.subplots??

# %%
fig,axes = plt.subplots(2,2,figsize=(10,10))
axes[0,0].set_title("sepal length")
axes[0,0].hist(df['sepal.length'],bins=7)

axes[0,1].set_title("sepal width")
axes[0,1].hist(df['sepal.width'],bins=5)

axes[1,0].set_title("petal lenght")
axes[1,0].hist(df['petal.length'],bins=6)

axes[1,1].set_title("sepal width")
axes[1,1].hist(df['petal.width'],bins=6)
# Out:
# (array([48.,  2., 15., 37., 25., 23.]),
#  array([0.1, 0.5, 0.9, 1.3, 1.7, 2.1, 2.5]),
#  <BarContainer object of 6 artists>)

# %%
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.displot,'sepal.length').add_legend()
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.displot,'sepal.width').add_legend()
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.displot,'petal.length').add_legend()
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.displot,'petal.width').add_legend()
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\CSELAB1SYS10\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\CSELAB1SYS10\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.histplot,'sepal.length').add_legend()
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.histplot,'sepal.width').add_legend()
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.histplot,'petal.length').add_legend()
plot = sns.FacetGrid(df, hue="variety")
plot.map(sns.histplot,'petal.width').add_legend()

# %%
def graph(y):
    sns.boxplot(x='variety', y=y , data=df)

# %%
plt.figure(figsize=(10,10))

# %%
plt.subplot(221)
graph('sepal.length')

# %%
plt.subplot(222)
graph('sepal.width')

# %%
plt.subplot(223)
graph('petal.length')

# %%
plt.subplot(224)
graph('petal.width')

# %%
data = df.drop_duplicates(subset='variety')

# %%
data.corr(method='pearson')
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_1172\2721894934.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr(method='pearson')
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.999226      0.795795     0.643817
# sepal.width      -0.999226     1.000000     -0.818999    -0.673417
# petal.length      0.795795    -0.818999      1.000000     0.975713
# petal.width       0.643817    -0.673417      0.975713     1.000000

# %%
sns.heatmap(data.corr(method='pearson'),annot = True)
# Out:
# C:\Users\CSELAB1SYS10\AppData\Local\Temp\ipykernel_1172\1271692383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(method='pearson'),annot = True)
# <AxesSubplot: >
